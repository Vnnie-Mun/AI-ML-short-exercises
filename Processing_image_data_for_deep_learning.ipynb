# %% [markdown]
# <a href="https://colab.research.google.com/github/Vnnie-Mun/AI-ML_full-projects_repository/blob/main/Processing_image_data_for_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting an image using web get

# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s'
# Out:
# --2025-07-10 05:49:06--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 74.125.195.113, 74.125.195.139, 74.125.195.101, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|74.125.195.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4859 (4.7K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s.2’
#
# images?q=tbn:ANd9Gc 100%[===================>]   4.75K  --.-KB/s    in 0s
#
# 2025-07-10 05:49:06 (68.3 MB/s) - ‘images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s.2’ saved [4859/4859]

# %% [markdown]
#  matplotlib.image
#  pillow
# openCV

# %%
 #libraries that can be used for image processing

#importing the image odule from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
import matplotlib.image as mpimg

img = mpimg.imread('/content/images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
import cv2
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (194, 259)

# %% [markdown]
# cv2.imshow() will display the image.But this will not be allowed in google Colab
#
#
# from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=259x194>

# %%
#saving the grayscale image
cv2.imwrite('grayscale_image.jpg',grayscale_image)
# Out:
# True

# %% [markdown]
# resizing the image using pillow library

# %%
from PIL import Image

# %%
img =Image.open('/content/images?q=tbn:ANd9GcTnWy78W-5g-tqwHO1CtVeaOK4jHjdHJ_rpwQ&s')

img_resize = img.resize((400,400))

# %%
img_resize.save('Dog_image_resized.jpg')

# %%
#displaying the image from numpy array

img_res = mpimg.imread('/content/Dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()
